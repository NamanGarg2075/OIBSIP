# %% [markdown]
# # Car Price Prediction - TASK #03

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ### Information about data

# %%
df = pd.read_csv("./CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber
# 0       1          3        alfa-romero giulia      gas        std        two  \
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize
# 0  convertible        rwd          front       88.6  ...         130  \
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber
# 200     201         -1  volvo 145e (sw)      gas        std       four  \
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem
# 200   sedan        rwd          front      109.1  ...         141        mpfi  \
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg
# ...

# %%
df.sample(5)
# Out:
#      car_ID  symboling              CarName fueltype aspiration doornumber
# 9        10          0  audi 5000s (diesel)      gas      turbo        two  \
# 134     135          3            saab 99le      gas        std        two
# 21       22          1        dodge rampage      gas        std        two
# 48       49          0            jaguar xf      gas        std       four
# 69       70          0        buick century   diesel      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize
# 9    hatchback        4wd          front       99.5  ...         131  \
# 134  hatchback        fwd          front       99.1  ...         121
# 21   hatchback        fwd          front       93.7  ...          90
# 48       sedan        rwd          front      113.0  ...         258
# 69     hardtop        rwd          front      106.7  ...         183
#
#      fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
# taking only required columns
df = df[['enginesize','carlength','carwidth','carheight','curbweight','wheelbase','stroke','horsepower','compressionratio','highwaympg','peakrpm','citympg','price']]

# %%
df.sample(5)
# Out:
#      enginesize  carlength  carwidth  carheight  curbweight  wheelbase
# 36           92      157.1      63.9       58.3        2024       96.5  \
# 101         181      181.7      66.5       55.1        3095      100.4
# 180         171      187.8      66.5       54.1        3131      104.5
# 65          140      175.0      66.1       54.4        2670      104.9
# 120          90      157.3      63.8       50.6        1967       93.7
#
#      stroke  horsepower  compressionratio  highwaympg  peakrpm  citympg
# 36     3.41          76               9.2          34     6000       30  \
# 101    3.27         152               9.0          22     5200       17
# 180    3.35         156               9.2          24     5200       20
# 65     3.16         120               8.0          27     5000       19
# 120    3.23          68               9.4          38     5500       31
#
#        price
# 36    7295.0
# 101  13499.0
# 180  15690.0
# 65   18280.0
# 120   6229.0

# %%
df.isna().sum()
# Out:
# enginesize          0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# wheelbase           0
# stroke              0
# horsepower          0
# compressionratio    0
# highwaympg          0
# peakrpm             0
# citympg             0
# price               0
# dtype: int64

# %% [markdown]
# Our data has no null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   enginesize        205 non-null    int64
#  1   carlength         205 non-null    float64
#  2   carwidth          205 non-null    float64
#  3   carheight         205 non-null    float64
#  4   curbweight        205 non-null    int64
#  5   wheelbase         205 non-null    float64
#  6   stroke            205 non-null    float64
#  7   horsepower        205 non-null    int64
#  8   compressionratio  205 non-null    float64
#  9   highwaympg        205 non-null    int64
#  10  peakrpm           205 non-null    int64
#  11  citympg           205 non-null    int64
#  12  price             205 non-null    float64
# dtypes: float64(7), int64(6)
# memory usage: 20.9 KB

# %%
df.describe()
# Out:
#        enginesize   carlength    carwidth   carheight   curbweight
# count  205.000000  205.000000  205.000000  205.000000   205.000000  \
# mean   126.907317  174.049268   65.907805   53.724878  2555.565854
# std     41.642693   12.337289    2.145204    2.443522   520.680204
# min     61.000000  141.100000   60.300000   47.800000  1488.000000
# 25%     97.000000  166.300000   64.100000   52.000000  2145.000000
# 50%    120.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    141.000000  183.100000   66.900000   55.500000  2935.000000
# max    326.000000  208.100000   72.300000   59.800000  4066.000000
#
#         wheelbase      stroke  horsepower  compressionratio  highwaympg
# count  205.000000  205.000000  205.000000        205.000000  205.000000  \
# mean    98.756585    3.255415  104.117073         10.142537   30.751220
# std      6.021776    0.313597   39.544167          3.972040    6.886443
# min     86.600000    2.070000   48.000000          7.000000   16.000000
# ...

# %% [markdown]
# ### Train Test Split

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=3)

# %% [markdown]
# ### Training Model

# %%
model = LinearRegression()
model.fit(X=X_train,y=y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8301682522378183

# %% [markdown]
# According to score our model is perfoming preety good :)
